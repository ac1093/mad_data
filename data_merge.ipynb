# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.wikipedia_db
collection = db.tables

# %%
url = 'https://en.wikipedia.org/wiki/List_of_wine-producing_regions'
url2 = 'https://en.wikipedia.org/wiki/List_of_countries_by_traffic-related_death_rate'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

# %%
tables =pd.read_html(url)
df= pd.DataFrame(tables[0])
df.head(10)
# Out:
#    Rank Country(with link to wine article)  Production(tonnes)
# 0     1                              Italy             4796900
# 1     2                              Spain             4607850
# 2     3                             France             4293466
# 3     4                      United States             3300000
# 4     5                              China             1700000
# 5     6                          Argentina             1498380
# 6     7                              Chile             1214000
# 7     8                          Australia             1186343
# 8     9                       South Africa             1146006
# 9    10                            Germany              920200

# %%
traffic_table = pd.read_html(url2)
traffic_df = pd.DataFrame(traffic_table[1])
traffic_df.head(10)
# Out:
#                  Country Continent  \
# 0                  World       NaN
# 1                 Africa       NaN
# 2  Eastern Mediterranean       NaN
# 3        Western Pacific       NaN
# 4        South-east Asia       NaN
# 5               Americas       NaN
# 6                 Europe       NaN
# 7            Afghanistan      Asia
# 8                Albania    Europe
# 9                Algeria    Africa
#
#   Road fatalitiesper 100,000inhabitantsper year[5][2]  \
# 0                                               18.2
# 1                                               26.6
# 2                                               18.0
# 3                                               16.9
# 4                                               20.7
# 5                                               15.6
# 6                                                  9
# 7                                               15.5
# 8                                               13.6
# 9                                               23.8
#
#   Road fatalitiesper 100,000motor vehicles[5][2]  \
# 0                                            NaN
# 1                                         574[7]
# 2                                         139[7]
# 3                                          69[7]
# 4                                         101[7]
# 5                                          33[7]
# 6                                          19[7]
# 7                                          722.4
# 8                                          107.2
# 9                                          127.8
#
#    Road fatalitiesper 1 billionvehicle-km[6]  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
#
#   Total fatalitieslatest year(adjusted/estimatedfigures by WHO report)[5][2]  \
# 0                                            1350000
# 1                                         246,719[7]
# 2                                         122,730[7]
# 3                                         328,591[7]
# 4                                         316,080[7]
# 5                                         153,789[7]
# 6                                          85,629[7]
# 7                                               4734
# 8                                                399
# 9                                               9337
#
#   Year, data source(standard source:The WHO report 2015,[3]data from 2013The WHO report 2018,[2]data from 2016)
# 0                                               2016
# 1                                               2016
# 2                                               2016
# 3                                               2016
# 4                                               2016
# 5                                               2016
# 6                                               2018
# 7                                               2013
# 8                                               2018
# 9                                               2013
